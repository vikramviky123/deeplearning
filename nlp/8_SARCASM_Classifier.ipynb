# %%
import os
import sys
from pathlib import Path

import pandas as pd
import numpy as np

from helper import *

import re
from typing import *

import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
url = 'https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json'

# %%
save_path = Path("data/sarcasm/sarcasm.json")

# %%
download_zip_file(url,save_path)
# Out:
# Download successful. File saved at data\sarcasm\sarcasm.json

# %%
df = pd.read_json(save_path)

# %%
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26709 entries, 0 to 26708
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   article_link  26709 non-null  object
#  1   headline      26709 non-null  object
#  2   is_sarcastic  26709 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 626.1+ KB

# %%
df['article_link'][0]
# Out:
# 'https://www.huffingtonpost.com/entry/versace-black-code_us_5861fbefe4b0de3a08f600d5'

# %%
def main_name(x):
    return re.findall(r'\.(.*?)\.', x)[0]

# %%
df['main_name'] = df['article_link'].apply(main_name)

# %%
df.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic  \
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
#
#         main_name
# 0  huffingtonpost
# 1  huffingtonpost
# 2        theonion
# 3        theonion
# 4  huffingtonpost

# %%
df['main_name'].value_counts(1)
# Out:
# huffingtonpost    0.561047
# theonion          0.438953
# Name: main_name, dtype: float64

# %%
sentences = df['headline'].to_list()
labels = df['is_sarcastic'].to_list()

# %%
sentences[:3], labels[:3]
# Out:
# (["former versace store clerk sues over secret 'black code' for minority shoppers",
#   "the 'roseanne' revival catches up to our thorny political mood, for better and worse",
#   "mom starting to fear son's web series closest thing she will have to grandchild"],
#  [0, 0, 1])

# %% [markdown]
# ### 1.Cleaning the Data

# %%
def clean_data(sentences:List):
    ps = PorterStemmer()
    corpus = []
    for i in range(0, len(sentences)):
        each_sentence = re.sub('[^a-zA-Z]', ' ', sentences[i])
        each_sentence = each_sentence.lower()
        each_sentence = each_sentence.split()

        each_sentence = [ps.stem(word)
                         for word in each_sentence if not word in stopwords.words('english')]
        each_sentence = ' '.join(each_sentence)
        corpus.append(each_sentence)
    return corpus

# %%
clean_sentences = clean_data(sentences)

# %%
clean_sentences[:3]
# Out:
# ['former versac store clerk sue secret black code minor shopper',
#  'roseann reviv catch thorni polit mood better wors',
#  'mom start fear son web seri closest thing grandchild']

# %% [markdown]
# ### 2.Train test Split

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(
    clean_sentences, labels, test_size=0.20, random_state=0, stratify=labels)

# %%
X_train[:3]
# Out:
# ['share hazmat suit maker spike nyc ebola news',
#  'miss america call u n council promot enough world peac',
#  'tarsier world smallest primat anim planet looney front part']

# %%
pd.Series(y_train).value_counts(1)
# Out:
# 0    0.561052
# 1    0.438948
# dtype: float64

# %%
pd.Series(y_test).value_counts(1)
# Out:
# 0    0.561026
# 1    0.438974
# dtype: float64

# %% [markdown]
# ### 3. Bag Of Words

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=10000)
cv_fit = cv.fit(X_train)
X_train_bow = cv_fit.transform(X_train).toarray()
X_test_bow = cv_fit.transform(X_test).toarray()

# %%
# Training model using Naive bayes classifier

spam_detect_model = MultinomialNB().fit(X_train_bow, y_train)

y_pred = spam_detect_model.predict(X_test_bow)
accuracy_score(y_test, y_pred)
# Out:
# 0.7912766754024709

# %% [markdown]
# ### 4. TF_IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf_idf = TfidfVectorizer(max_features=10000)
tf_idf_fit = tf_idf.fit(X_train)
X_train_tfidf = tf_idf_fit.transform(X_train).toarray()
X_test_tfidf = tf_idf_fit.transform(X_test).toarray()

# %%
# Training model using Naive bayes classifier

spam_detect_model = MultinomialNB().fit(X_train_tfidf, y_train)

y_pred = spam_detect_model.predict(X_test_tfidf)
accuracy_score(y_test, y_pred)
# Out:
# 0.7794833395731936

# %% [markdown]
# ### 5.TensorFlow Embeddings

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Vocabulary size of the tokenizer
vocab_size = 10000

# Maximum length of the padded sequences
max_length = 50

# Output dimensions of the Embedding layer
embedding_dim = 16

# %%
X_train[:3]
# Out:
# ['share hazmat suit maker spike nyc ebola news',
#  'miss america call u n council promot enough world peac',
#  'tarsier world smallest primat anim planet looney front part']

# %%
# Parameters for padding and OOV tokens
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(X_train)
word_index = tokenizer.word_index

# Generate and pad the training sequences
training_sequences = tokenizer.texts_to_sequences(X_train)
training_padded = pad_sequences(
    training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the testing sequences
testing_sequences = tokenizer.texts_to_sequences(X_test)
testing_padded = pad_sequences(
    testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Convert the labels lists into numpy arrays
training_labels = np.array(y_train)
testing_labels = np.array(y_test)

# %%
# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(
        vocab_size, embedding_dim, input_length=max_length,name="embedding"),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),    
    tf.keras.layers.Dropout(0.3),
    
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 16)            160000
#
#  flatten_3 (Flatten)         (None, 800)               0
#
#  dense_14 (Dense)            (None, 128)               102528
#
#  batch_normalization_9 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_15 (Dense)            (None, 64)                8256
#
#  batch_normalization_10 (Ba  (None, 64)                256
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_16 (Dense)            (None, 32)                2080
#
#  batch_normalization_11 (Ba  (None, 32)                128
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 273793 (1.04 MB)
# Trainable params: 273345 (1.04 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
                                                    monitor='val_loss',
                                                    min_delta=0.0001,
                                                    patience=5,
                                                    verbose=0,
                                                    mode='auto',
                                                    # baseline=None,
                                                    restore_best_weights=True,
                                                    start_from_epoch=0
                                                )

# %%
num_epochs = 30

# Train the model
history = model.fit(training_padded, 
                    training_labels, 
                    epochs=num_epochs,
                    validation_data=(testing_padded, testing_labels), 
                    verbose=2,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 668/668 - 8s - loss: 0.6871 - accuracy: 0.6206 - val_loss: 0.5303 - val_accuracy: 0.7325 - 8s/epoch - 12ms/step
# Epoch 2/30
# 668/668 - 5s - loss: 0.4363 - accuracy: 0.8031 - val_loss: 0.4721 - val_accuracy: 0.7898 - 5s/epoch - 8ms/step
# Epoch 3/30
# 668/668 - 6s - loss: 0.3037 - accuracy: 0.8773 - val_loss: 0.5316 - val_accuracy: 0.7780 - 6s/epoch - 8ms/step
# Epoch 4/30
# 668/668 - 4s - loss: 0.2043 - accuracy: 0.9237 - val_loss: 0.6327 - val_accuracy: 0.7651 - 4s/epoch - 7ms/step
# Epoch 5/30
# 668/668 - 4s - loss: 0.1457 - accuracy: 0.9467 - val_loss: 0.6819 - val_accuracy: 0.7838 - 4s/epoch - 6ms/step
# Epoch 6/30
# 668/668 - 4s - loss: 0.1189 - accuracy: 0.9583 - val_loss: 0.9031 - val_accuracy: 0.7244 - 4s/epoch - 6ms/step
# Epoch 7/30
# 668/668 - 4s - loss: 0.1022 - accuracy: 0.9616 - val_loss: 0.7677 - val_accuracy: 0.7731 - 4s/epoch - 6ms/step

# %%
model.evaluate(testing_padded,testing_labels)
# Out:
# 167/167 [==============================] - 1s 3ms/step - loss: 0.4721 - accuracy: 0.7898
# [0.47209474444389343, 0.7897791266441345]

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
myDict = history.history

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(myDict['loss'])
plt.plot(myDict['val_loss'])
plt.subplot(1,2,2)
plt.plot(myDict['accuracy'])
plt.plot(myDict['val_accuracy'])

# %%
print(word_index)
# Out:
# {'<OOV>': 1, 'trump': 2, 'new': 3, 'man': 4, 'year': 5, 'get': 6, 'say': 7, 'report': 8, 'make': 9, 'one': 10, 'day': 11, 'time': 12, 'area': 13, 'american': 14, 'woman': 15, 'nation': 16, 'u': 17, 'like': 18, 'donald': 19, 'first': 20, 'peopl': 21, 'obama': 22, 'take': 23, 'hous': 24, 'old': 25, 'go': 26, 'way': 27, 'world': 28, 'women': 29, 'life': 30, 'show': 31, 'call': 32, 'find': 33, 'thing': 34, 'back': 35, 'look': 36, 'clinton': 37, 'white': 38, 'famili': 39, 'want': 40, 'still': 41, 'school': 42, 'state': 43, 'work': 44, 'live': 45, 'watch': 46, 'plan': 47, 'need': 48, 'love': 49, 'know': 50, 'use': 51, 'could': 52, 'right': 53, 'come': 54, 'presid': 55, 'chang': 56, 'black': 57, 'gop': 58, 'mom': 59, 'give': 60, 'think': 61, 'home': 62, 'parent': 63, 'kid': 64, 'kill': 65, 'bill': 66, 'last': 67, 'studi': 68, 'talk': 69, 'star': 70, 'best': 71, 'america': 72, 'polic': 73, 'would': 74, 'ask': 75, 'friend': 76, 'realli': 77, 'student': 78, 'tri': 79, 'help': 80, 'good': 81, 'death': 82, 'see': 83, 'elect': 84, 'tell': 85, 'video': 86, 'senat': 87, 'war': 88, 'die': 89, 'hillari': 90, 'health': 91, 'girl': 92, 'run': 93, 'open': 94, 'stop': 95, 'offic': 96, 'republican': 97, 'may': 98, 'campaign': 99, 'parti': 100, 'child': 101, 'million': 102, 'big': 103, 'win': 104, 'game': 105, 'attack': 106, 'fire': 107, 'gay': 108, 'self': 109, 'support': 110, 'name': 111, 'week': 112, 'guy': 113, 'everi': 114, 'court': 115, 'fight': 116, 'reveal': 117, 'final': 118, 'vote': 119, 'person': 120, 'dad': 121, 'celebr': 122, 'break': 123, 'photo': 124, 'dog': 125, 'dead': 126, 'high': 127, 'forc': 128, 'gun': 129, 'meet': 130, 'care': 131, 'announc': 132, 'power': 133, 'shoot': 134, 'feel': 135, 'real': 136, 'littl': 137, 'busi': 138, 'job': 139, 'let': 140, 'never': 141, 'democrat': 142, 'babi': 143, 'end': 144, 'teen': 145, 'leav': 146, 'fan': 147, 'local': 148, 'news': 149, 'even': 150, 'actual': 151, 'hope': 152, 'debat': 153, 'keep': 154, 'john': 155, 'coupl': 156, 'colleg': 157, 'save': 158, 'put': 159, 'face': 160, 'start': 161, 'releas': 162, 'miss': 163, 'stori': 164, 'citi': 165, 'movi': 166, 'made': 167, 'night': 168, 'bush': 169, 'sex': 170, 'turn': 171, 'law': 172, 'season': 173, 'sexual': 174, 'son': 175, 'around': 176, 'next': 177, 'move': 178, 'anoth': 179, 'us': 180, 'protest': 181, 'top': 182, 'book': 183, 'ever': 184, 'minut': 185, 'got': 186, 'human': 187, 'much': 188, 'two': 189, 'food': 190, 'polit': 191, 'mother': 192, 'play': 193, 'film': 194, 'north': 195, 'car': 196, 'deal': 197, 'month': 198, 'long': 199, 'children': 200, 'eat': 201, 'warn': 202, 'free': 203, 'employe': 204, 'line': 205, 'god': 206, 'rule': 207, 'second': 208, 'learn': 209, 'fuck': 210, 'hit': 211, 'bodi': 212, 'return': 213, 'bad': 214, 'away': 215, 'money': 216, 'climat': 217, 'compani': 218, 'head': 219, 'offici': 220, 'better': 221, 'candid': 222, 'tv': 223, 'congress': 224, 'ad': 225, 'claim': 226, 'word': 227, 'govern': 228, 'introduc': 229, 'voter': 230, 'hour': 231, 'wed': 232, 'histori': 233, 'bring': 234, 'teacher': 235, 'paul': 236, 'boy': 237, 'reason': 238, 'men': 239, 'lead': 240, 'media': 241, 'tax': 242, 'immigr': 243, 'cop': 244, 'york': 245, 'age': 246, 'ban': 247, 'date': 248, 'father': 249, 'post': 250, 'anti': 251, 'leader': 252, 'countri': 253, 'group': 254, 'hand': 255, 'email': 256, 'order': 257, 'set': 258, 'poll': 259, 'spend': 260, 'secret': 261, 'without': 262, 'beauti': 263, 'pope': 264, 'fail': 265, 'happen': 266, 'pay': 267, 'facebook': 268, 'public': 269, 'everyon': 270, 'suprem': 271, 'case': 272, 'control': 273, 'great': 274, 'entir': 275, 'found': 276, 'question': 277, 'sander': 278, 'idea': 279, 'pass': 280, 'music': 281, 'singl': 282, 'place': 283, 'sign': 284, 'pretti': 285, 'offer': 286, 'record': 287, 'enough': 288, 'tweet': 289, 'walk': 290, 'lose': 291, 'dream': 292, 'becom': 293, 'cover': 294, 'respons': 295, 'former': 296, 'daughter': 297, 'futur': 298, 'morn': 299, 'race': 300, 'wait': 301, 'surpri ...

# %%
print(word_index['minnesota'])
print(word_index['wisconsin'])
# Out:
# 2125
# 2196

# %%
print(word_index['man'])
print(word_index['woman'])
# Out:
# 4
# 15

# %%
embedding_layer = model.get_layer('embedding').get_weights()[0]

# %%
embedding_layer[3]
# Out:
# array([ 0.04204768,  0.0179944 ,  0.00223803, -0.06641978, -0.05038901,
#        -0.04895205, -0.01433265,  0.04349722,  0.02094213,  0.01272332,
#         0.0080289 ,  0.05831825,  0.05810782,  0.00187868,  0.04901073,
#         0.03464374], dtype=float32)

# %%
embedding_layer[14]
# Out:
# array([ 0.02074746,  0.00693405,  0.01041315, -0.03471129,  0.00838813,
#         0.02742559,  0.03354286, -0.03659568, -0.08252362, -0.02591295,
#        -0.00459373, -0.02845839,  0.00024439, -0.0596348 , -0.03620374,
#        -0.03341204], dtype=float32)

# %%
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances
from scipy.spatial.distance import cosine

# %%
# Assuming embedding_layer[2124] and embedding_layer[2195] are 1D arrays
embedding1 = np.array(embedding_layer[2124]).reshape(1, -1)
embedding2 = np.array(embedding_layer[2195]).reshape(1, -1)

embedding3 = np.array(embedding_layer[3]).reshape(1, -1)
embedding4 = np.array(embedding_layer[14]).reshape(1, -1)

# Calculate cosine similarity
similarity1 = cosine_similarity(embedding1, embedding2)
similarity2 = cosine_similarity(embedding3, embedding4)

print(f"Cosine Similarity: {similarity1[0, 0]}")
print(f"Cosine Similarity: {similarity2[0, 0]}")
# Out:
# Cosine Similarity: 0.10796086490154266
# Cosine Similarity: -0.33426448702812195

# %%
print(1-cosine(embedding_layer[2124], embedding_layer[2195]))
# Out:
# 0.10796087980270386

# %%
print(1-cosine(embedding_layer[3], embedding_layer[14]))
# Out:
# -0.33426445722579956
